# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Carlo\Desktop\Todo el proyecto\Proyecto\DATA TOTAL\Data Terminada.csv")

# %%
data
# Out:
#                        Name  Goals  Big chances missed  Successful dribbles %  \
# 0              Akram Tawfik   0.13                0.00                  55.56
# 1               Ali Maâloul   0.32                0.00                  65.22
# 2                Karim Emad   0.00                0.00                   0.00
# 3                      Zizo   0.38                0.21                  42.40
# 4             Mohamed Chibi   0.00                0.00                  68.75
# ...                     ...    ...                 ...                    ...
# 23785      Federico Girotti   0.00                0.00                   0.00
# 23786  Maximiliano González   0.00                0.00                 100.00
# 23787      Matías Hernández   0.00                0.00                   0.00
# 23788             Kevin Isa   0.00                0.00                   0.00
# 23789          Matías Gómez   0.00                0.00                   0.00
#
# ...

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

Columna_habilidades = data.columns.drop(["Name", "League"])

features = data[Columna_habilidades]

features['Level'] = features['Level'] * 1.5
features['Appearances'] = features['Appearances'] * 2.5
features['Goals'] = features['Goals'] * 2.5
features['Total shots'] = features['Total shots'] * 0.5

# Crea un objeto StandardScaler
scaler = StandardScaler()

# Ajusta el escalador a tus datos y luego transforma tus datos
features_scaled = scaler.fit_transform(features)

# Inicializa el modelo NearestNeighbors
model = NearestNeighbors(n_neighbors=6)  # Buscamos 6 vecinos porque uno de ellos será el jugador mismo

# Ajusta el modelo a tus datos
model.fit(features_scaled)
# Out:
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\875994632.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\875994632.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\875994632.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import plotly.graph_objects as go

def buscar_jugadores_similares(nombre, caracteristicas_grafico):
    jugador = data[data['Name'] == nombre]
    if len(jugador) == 0:
        return 'Jugador no encontrado'
    else:
        jugador_scaled = scaler.transform(jugador[features.columns])
        distancias, indices = model.kneighbors(jugador_scaled)
        jugadores_similares = data.iloc[indices[0][1:]]  # Excluimos el primer resultado porque será el jugador mismo

        # Escala todas las características de los jugadores similares
        jugadores_similares_scaled = scaler.transform(jugadores_similares[features.columns])

        # Crea un gráfico de radar para cada jugador similar
        fig = go.Figure()
        for i, row in enumerate(jugadores_similares_scaled):
            fig.add_trace(go.Scatterpolar(
                r=row[features.columns.isin(caracteristicas_grafico)],
                theta=caracteristicas_grafico,
                fill='toself',
                name=jugadores_similares.iloc[i]['Name']
            ))
        fig.update_layout(
            autosize=False,
            width=800,
            height=800,
            polar=dict(
                radialaxis=dict(
                    visible=True,
                    range=[-2, 10]  # Ajusta este rango según tus datos
                )),
            showlegend=True
        )
        fig.show()

        return jugadores_similares

# %%
caracteristicas_grafico = ["Goals", "Big chances missed", "Successful dribbles %", "Total shots", "Headed goals"]

# %%
#pd.set_option('display.max_columns', None)
buscar_jugadores_similares('Franco Frías', caracteristicas_grafico)
# Out:
#                    Name  Goals  Big chances missed  Successful dribbles %  \
# 19532    Mathias Honsak   0.27                0.40                  33.33
# 23463       José Romero   0.22                0.33                  44.44
# 9388   Asier Villalibre   0.25                0.31                  50.00
# 23407      Mauro Méndez   0.21                0.26                  46.15
# 23453       Ivo Mammini   0.12                0.06                  32.14
#
#        Total shots  Headed goals  Set piece conversion %  Tackles  \
# 19532         1.87          0.13                     0.0     0.40
# 23463         1.33          0.11                     0.0     0.11
# 9388          1.81          0.19                     0.0     0.25
# 23407         1.58          0.11                     0.0     0.16
# 23453         1.29          0.12                     0.0     0.41
#
#        Interceptions  Penalty committed  Clearances  Errors lead to goal  \
# ...

# %% [markdown]
# # División DataFrame por posiciones

# %%
Porteros = data[data['Position'] == 1]

# %%
import os

Porteros.reset_index(drop=True, inplace=True)

# y que la carpeta "DATO" ya existe en el directorio actual

carpeta_destino = r"C:\Users\Carlo\Desktop\Todo el proyecto\Data Posición"
nombre_archivo = "Porteros.csv"

# Combina la carpeta y el nombre del archivo para obtener la ruta completa
ruta_completa = os.path.join(carpeta_destino, nombre_archivo)

# Guarda el DataFrame en el archivo CSV con la ruta completa
Porteros.to_csv(ruta_completa, index=False)

# %%
Porteros
# Out:
#                        Name  Goals  Big chances missed  Successful dribbles %  \
# 0                Karim Emad    0.0                 0.0                    0.0
# 1         Abdelrahman Samir    0.0                 0.0                    0.0
# 2             Essam Tharwat    0.0                 0.0                    0.0
# 3        Mohamed El-Shenawy    0.0                 0.0                    0.0
# 4                 Ali Lotfi    0.0                 0.0                    0.0
# ...                     ...    ...                 ...                    ...
# 1766        Agustin Quiroga    0.0                 0.0                    0.0
# 1767           Daniel Sappa    0.0                 0.0                  100.0
# 1768  Dante Nicolas Campisi    0.0                 0.0                    0.0
# 1769     Ezequiel Centurión    0.0                 0.0                    0.0
# 1770        Rodrigo Saracho    0.0                 0.0                    0.0
#
# ...

# %%
Defensas = data[data['Position'] == 2]

# %%
import os

Defensas.reset_index(drop=True, inplace=True)

# y que la carpeta "DATO" ya existe en el directorio actual

carpeta_destino = r"C:\Users\Carlo\Desktop\Todo el proyecto\Data Posición"
nombre_archivo = "Defensas.csv"

# Combina la carpeta y el nombre del archivo para obtener la ruta completa
ruta_completa = os.path.join(carpeta_destino, nombre_archivo)

# Guarda el DataFrame en el archivo CSV con la ruta completa
Defensas.to_csv(ruta_completa, index=False)

# %%
Defensas
# Out:
#                     Name  Goals  Big chances missed  Successful dribbles %  \
# 0            Ali Maâloul   0.32                 0.0                  65.22
# 1          Mohamed Chibi   0.00                 0.0                  68.75
# 2            Osama Galal   0.08                 0.0                  71.43
# 3       Ahmed Abdel Aziz   0.00                 0.0                   0.00
# 4           Mohamed Hany   0.00                 0.0                  40.00
# ...                  ...    ...                 ...                    ...
# 7419       Brian Aguilar   0.00                 0.0                   0.00
# 7420  Juan Pablo Pignani   0.00                 0.0                   0.00
# 7421    Santiago Morales   0.00                 0.0                   0.00
# 7422   Vicente Fernández   0.00                 0.0                  50.00
# 7423        Nahuel Genez   0.00                 0.0                  40.00
#
#       Total shots  Headed goals  Set piece conversion %  Tackles  \
# ...

# %%
Medios = data[data['Position'] == 3]

# %%
import os

Medios.reset_index(drop=True, inplace=True)

# y que la carpeta "DATO" ya existe en el directorio actual

carpeta_destino = r"C:\Users\Carlo\Desktop\Todo el proyecto\Data Posición"
nombre_archivo = "Medios.csv"

# Combina la carpeta y el nombre del archivo para obtener la ruta completa
ruta_completa = os.path.join(carpeta_destino, nombre_archivo)

# Guarda el DataFrame en el archivo CSV con la ruta completa
Medios.to_csv(ruta_completa, index=False)

# %%
Medios
# Out:
#                       Name  Goals  Big chances missed  Successful dribbles %  \
# 0             Akram Tawfik   0.13                0.00                  55.56
# 1                     Zizo   0.38                0.21                  42.40
# 2            Hossam Hassan   0.00                0.00                 100.00
# 3              Emam Ashour   0.13                0.13                  44.44
# 4      Mohamed Magdy Afsha   0.10                0.03                  56.25
# ...                    ...    ...                 ...                    ...
# 9329   Valentino Venetucci   0.00                0.00                   0.00
# 9330          Enzo Rivamar   0.00                0.00                   0.00
# 9331           Siro Rosane   0.00                0.00                 100.00
# 9332           Tomás Ortiz   0.00                0.00                   0.00
# 9333  Maximiliano González   0.00                0.00                 100.00
#
# ...

# %%
Delanteros = data[data['Position'] == 4]

# %%
import os

Delanteros.reset_index(drop=True, inplace=True)

# y que la carpeta "DATO" ya existe en el directorio actual

carpeta_destino = r"C:\Users\Carlo\Desktop\Todo el proyecto\Data Posición"
nombre_archivo = "Delanteros.csv"

# Combina la carpeta y el nombre del archivo para obtener la ruta completa
ruta_completa = os.path.join(carpeta_destino, nombre_archivo)

# Guarda el DataFrame en el archivo CSV con la ruta completa
Delanteros.to_csv(ruta_completa, index=False)

# %%
Delanteros
# Out:
#                     Name  Goals  Big chances missed  Successful dribbles %  \
# 0            Samir Fekri   0.27                0.12                  43.55
# 1               Mabululu   0.50                0.19                  51.28
# 2            Adnan Osman   0.00                0.00                   0.00
# 3        Ahmed Amin Oufa   0.37                0.19                  48.33
# 4     Mohamed Hamdy Zaki   0.43                0.21                  28.57
# ...                  ...    ...                 ...                    ...
# 5256      Santiago Lopez   0.00                0.00                  50.00
# 5257    Federico Girotti   0.00                0.00                   0.00
# 5258    Matías Hernández   0.00                0.00                   0.00
# 5259           Kevin Isa   0.00                0.00                   0.00
# 5260        Matías Gómez   0.00                0.00                   0.00
#
#       Total shots  Headed goals  Set piece conversion %  Tackles  \
# ...

# %% [markdown]
# # Usar El modelos por posición

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

Columna_habilidades = Delanteros.columns.drop(["Name", "League"])

features = Delanteros[Columna_habilidades]

features['Level'] = features['Level'] * 5.5
features['Appearances'] = features['Appearances'] * 2.5
features['Goals'] = features['Goals'] * 2.5


# Crea un objeto StandardScaler
scaler = StandardScaler()

# Ajusta el escalador a tus datos y luego transforma tus datos
features_scaled = scaler.fit_transform(features)

# Inicializa el modelo NearestNeighbors
model = NearestNeighbors(n_neighbors=6)  # Buscamos 6 vecinos porque uno de ellos será el jugador mismo

# Ajusta el modelo a tus datos
model.fit(features_scaled)
# Out:
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\516426096.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\516426096.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\516426096.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import plotly.graph_objects as go

def buscar_jugadores_similares(nombre, caracteristicas_grafico):
    jugador = Delanteros[Delanteros['Name'] == nombre]
    if len(jugador) == 0:
        return 'Jugador no encontrado'
    else:
        jugador_scaled = scaler.transform(jugador[features.columns])
        distancias, indices = model.kneighbors(jugador_scaled)
        jugadores_similares = Delanteros.iloc[indices[0][1:]]  # Excluimos el primer resultado porque será el jugador mismo

        # Escala todas las características de los jugadores similares
        jugadores_similares_scaled = scaler.transform(jugadores_similares[features.columns])

        # Crea un gráfico de radar para cada jugador similar
        fig = go.Figure()
        for i, row in enumerate(jugadores_similares_scaled):
            fig.add_trace(go.Scatterpolar(
                r=row[features.columns.isin(caracteristicas_grafico)],
                theta=caracteristicas_grafico,
                fill='toself',
                name=jugadores_similares.iloc[i]['Name']
            ))
        fig.update_layout(
            autosize=False,
            width=800,
            height=800,
            polar=dict(
                radialaxis=dict(
                    visible=True,
                    range=[-2, 10]  # Ajusta este rango según tus datos
                )),
            showlegend=True
        )
        fig.show()

        return jugadores_similares

# %%
buscar_jugadores_similares('Chris Ramos', caracteristicas_grafico)
# Out:
#                Name  Goals  Big chances missed  Successful dribbles %  \
# 4952   Vedat Muriqi   0.43                0.31                  44.44
# 2166   Steve Mounié   0.26                0.35                  52.63
# 4306  Phillip Tietz   0.35                0.53                  34.04
# 829   Jhonder Cádiz   0.17                0.33                  38.89
# 3834      Deyverson   0.33                0.28                  51.06
#
#       Total shots  Headed goals  Set piece conversion %  Tackles  \
# 4952         2.17          0.14                    0.00     0.34
# 2166         2.57          0.13                    0.00     0.57
# 4306         2.85          0.12                    0.98     0.47
# 829          1.92          0.13                    0.00     0.25
# 3834         1.94          0.14                    0.00     0.33
#
#       Interceptions  Penalty committed  Clearances  Errors lead to goal  \
# 4952           0.34                0.0        2.09                  0.0
# ...

# %%
import dill
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go

# Supongamos que ya tienes cargado el DataFrame Delanteros y has realizado las transformaciones necesarias

Columna_habilidades = Delanteros.columns.drop(["Name", "League"])
features = Delanteros[Columna_habilidades]
features['Level'] = features['Level'] * 5.5
features['Appearances'] = features['Appearances'] * 2.5
features['Goals'] = features['Goals'] * 2.5

# Crea un objeto StandardScaler
scaler = StandardScaler()

# Ajusta el escalador a tus datos y luego transforma tus datos
features_scaled = scaler.fit_transform(features)

# Inicializa el modelo NearestNeighbors
model = NearestNeighbors(n_neighbors=6)  # Buscamos 6 vecinos porque uno de ellos será el jugador mismo

# Ajusta el modelo a tus datos
model.fit(features_scaled)

# Función para buscar jugadores similares y mostrar un gráfico de radar
def buscar_jugadores_similares(nombre, caracteristicas_grafico):
    jugador = Delanteros[Delanteros['Name'] == nombre]
    if len(jugador) == 0:
        return 'Jugador no encontrado'
    else:
        jugador_scaled = scaler.transform(jugador[features.columns])
        distancias, indices = model.kneighbors(jugador_scaled)
        jugadores_similares = Delanteros.iloc[indices[0][1:]]  # Excluimos el primer resultado porque será el jugador mismo

        # Escala todas las características de los jugadores similares
        jugadores_similares_scaled = scaler.transform(jugadores_similares[features.columns])

        # Crea un gráfico de radar para cada jugador similar
        fig = go.Figure()
        for i, row in enumerate(jugadores_similares_scaled):
            fig.add_trace(go.Scatterpolar(
                r=row[features.columns.isin(caracteristicas_grafico)],
                theta=caracteristicas_grafico,
                fill='toself',
                name=jugadores_similares.iloc[i]['Name']
            ))
        fig.update_layout(
            autosize=False,
            width=800,
            height=800,
            polar=dict(
                radialaxis=dict(
                    visible=True,
                    range=[-2, 10]  # Ajusta este rango según tus datos
                )),
            showlegend=True
        )
        fig.show()

        return jugadores_similares

# Guardar modelo y función en un archivo
carpeta_guardado = r"C:\Users\Carlo\Desktop\Todo el proyecto\Modelos"
ruta_guardado = os.path.join(carpeta_guardado, "modelo_y_funcion-Delanteros.dill")
with open(ruta_guardado, 'wb') as archivo:
    dill.dump({
        'model': model,
        'scaler': scaler,
        'features_columns': features.columns,
        'caracteristicas_grafico': Columna_habilidades.tolist(),
        'buscar_jugadores_similares': buscar_jugadores_similares,
        'Delanteros': Delanteros
    }, archivo)
# Out:
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\1813070332.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\1813070332.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Carlo\AppData\Local\Temp\ipykernel_51652\1813070332.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
